# %%
OPENAI_KEY = "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"

# %%
from PyPDF2 import PdfReader
from PIL import Image
import fitz

# %%
from pdf2image import convert_from_path
import glob

# %%
reader = PdfReader("./raw_data/0006/00068790.pdf")

pdf_string_2 = ''

for page in range(len(reader.pages)):
    pdf_string_2 += reader.pages[page].extract_text()

# %%
print(pdf_string_2)

# %%
doc = fitz.open('./raw_data/0006/00068790.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 doc = fitz.open('./raw_data/0006/00068790.pdf')
#
# AttributeError: module 'fitz' has no attribute 'open'

# %%
for page in doc:
    pix = page.get_pixmap()
    pix.save(f'{page}.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 for page in doc:
#       2     pix = page.get_pixmap()
#       3     pix.save(f'{page}.png')
#
# NameError: name 'doc' is not defined

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

# %%
ocrd_text = pytesseract.image_to_string(Image.open('page 0 of kmeans_algorithm.pdf.png'))

# %%
print(ocrd_text)

# %%
glob.glob('./raw_data/0004/00049397.pdf')
# Out:
# ['./raw_data/0004/00049397.pdf']

# %%
pages = convert_from_path('./raw_data/0004/00049397.pdf', 50)
pages[0]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=425x550>

# %%
pages[0].save('./sample_page.jpg', "JPEG")

# %%
import pytesseract

# %%
ocrd_text = pytesseract.image_to_string(Image.open('./sample_page.jpg'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/pytorch/lib/python3.11/site-packages/pytesseract/pytesseract.py:255, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254 try:
# --> 255     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256 except OSError as e:
#
# File ~/miniconda3/envs/pytorch/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# ...
